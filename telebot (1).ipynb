# %%
# !pip install --upgrade pyTelegramBotAPI
# Out:
# ...
#   Obtaining dependency information for pyTelegramBotAPI from https://files.pythonhosted.org/packages/99/44/c253cd74d3fde09cb38c557e0319971bb4c57064ce05e1e6eb2c6cc5f411/pytelegrambotapi-4.22.1-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/48.2 kB ? eta -:--:--
#      ------------------------- -------------- 30.7/48.2 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 48.2/48.2 kB 601.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/261.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/261.0 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/261.0 kB 991.0 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/261.0 kB 991.0 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/261.0 kB 365.7 kB/s eta 0:00:01
#    ---------- ---------------------------- 71.7/261.0 kB 357.2 kB/s eta 0:00:01
# ...

# %%
# Setup the environment
# !pip install -q -U immutabledict sentencepiece
# !pip install -U transformers datasets
# !pip install ipywidgets
# !pip install telebot
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "D:\Program Files\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\Program Files\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "D:\Program Files\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\Program Files\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
# %%capture
# Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.27" "trl<0.9.0" peft accelerate bitsandbytes
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "D:\Program Files\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\Program Files\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "D:\Program Files\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\Program Files\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 4096 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gemma-2-9b-it",
    max_seq_length = max_seq_length,
    dtype = dtype,
)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "D:\Program Files\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\Program Files\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "D:\Program Files\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\Program Files\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# %%
device = "cuda:0"

prompt_template = '''<start_of_turn>user You are an AI assistant designed to write simple Java code, Please answer with the listing of the Java code.
Question: Please write a function in Java to calculate the area of a circle of radius r  Answer: <end_of_turn>
<start_of_turn>model'''

inputs = tokenizer(prompt_template, return_tensors="pt", add_special_tokens=True)

model_inputs = inputs.to(device)

# %%
from transformers import TextStreamer


text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(input_ids = inputs.input_ids, attention_mask = inputs.attention_mask,
                   streamer = text_streamer, max_new_tokens = 512, pad_token_id = tokenizer.eos_token_id)
# Out:
# ```java
# public class CircleArea {
#
#     public static double calculateArea(double r) {
#         return Math.PI * r * r;
#     }
#
#     public static void main(String[] args) {
#         double radius = 5.0;
#         double area = calculateArea(radius);
#         System.out.println("The area of the circle with radius " + radius + " is " + area);
#     }
# }
# ```
#
#
# **Explanation:**
#
# * **`public class CircleArea`**: This line defines a public class named `CircleArea`. Java code is organized into classes.
# * **`public static double calculateArea(double r)`**: This line defines a public static method named `calculateArea`.
#     * `public`:  Means this method can be accessed from anywhere.
#     * `static`: Means this method belongs to the class itself, not to any specific object of the class.
#     * `double`:  Indicates that the method returns a value of type `double` (a number with decimals).
#     * `calculateArea`: The name of the method.
# ...

# %%
# !pip install python-telegram-bot
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.9 MB/s eta 0:00:00
# ...

# %%
import os
os.mkdir('chats') # make a folder where we can save history by user

# %%
def java_ans(chat):
    system_variable = {"role":"user","content":"You are an AI Assistant for programmers. Your name is JavaSage. Your job is to assist programmers in Java language specifically "}
    additional_variable = {"role":"assistant","content":"Understood. I'm JavaSage, ready to assist with Java programming questions."}
    chat.insert(0,system_variable)
    chat.insert(1,additional_variable)
    prompt = tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True)
    inputs = tokenizer.encode(prompt, add_special_tokens=False, return_tensors="pt")
    outputs = model.generate(input_ids=inputs.to(model.device), max_new_tokens=1000)
    output = tokenizer.decode(outputs[0]).split('model\n')[-1]
    return output

# %%
import pandas as pd
########### GET CHATS BY USER ID ##################
def get_chats(id):
    path = id
    isexist = os.path.exists(path)
    if isexist:
        data = pd.read_json(path)
        chats = data.chat
        return list(chats)
    else:
        return "No Chat found on this User ID."

# %%
import json
############### APPEND NEW CHAT TO USER ID JSON FILE #################
def write_chat(new_data, id):
    with open(id,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        # Join new_data with file_data inside emp_details
        file_data["chat"].append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file, indent = 4)

# %%
def handle_chats(ids,prompt):
    path = str(os.getcwd()) + '//chats//' + (ids if ids is not None else 'default_id') + '.json'
    isexist = os.path.exists(path)
    if isexist:
        write_chat({"role":"user","content":prompt},path)
        print("User : ",prompt)
        chats = get_chats(path)
        send = java_ans(chats)
        reply = send
        print("JavaSage: ",reply)
        write_chat({"role":"assistant","content":reply},path)
        return reply
    else:
        dictionary = {
            "user_id":ids,
            "chat":[]
        }
        json_object = json.dumps(dictionary, indent=4)
        with open(path, "w") as outfile:
            outfile.write(json_object)
        reply = handle_chats(ids,prompt)
        return reply

# %%
telegram_token = "7266306547:AAH3R0ndm93hR80yd2JJJWUaiBilOJruRCI"

# %%
import telebot

# Telegram bot setup
bot = telebot.TeleBot(telegram_token)

@bot.message_handler(commands=['start',"restart"])
def send_welcome(message):
    bot.reply_to(message, "Hello! I'm JavaSage, your Java programming assistant. How can I help you today?")

@bot.message_handler()
def echo_all(message):
    user = message.from_user.username
    prompts = message.text
    prompt = prompts.replace("/chat","")
    ans = handle_chats(user,prompt)
    print(ans)
    bot.reply_to(message, ans)

# Start the bot
bot.infinity_polling()
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# User :  ما هي oop
# User :  اريد كود لطباعة عمران في الجافا
# 2024-08-12 11:17:59,929 (__init__.py:1096 MainThread) ERROR - TeleBot: "Infinity polling exception: paged_attention_K"
# ERROR:TeleBot:Infinity polling exception: paged_attention_K
# 2024-08-12 11:17:59,934 (__init__.py:1098 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/telebot/__init__.py", line 1091, in infinity_polling
# ...
